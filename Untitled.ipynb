# %%
import pandas as pd
import numpy as np

# %%
df_general = pd.read_csv('C:\\users\keval\Downloads\heroku_general_contract.csv')
df_award = pd.read_csv('C:\\users\keval\Downloads\heroku_contract_award.csv')

# %%
x = set(df_award['ProjectNumber'].tolist())
y = set(df_general['ProjectNumber'].tolist())

# %%
print("General: {}\nAward: {}\nIntersection: {}".format(len(x),len(y),len(x.intersection(y))))
# Out:
# General: 7060
# Award: 19715
# Intersection: 3276

# %%
df_general['ProjectNumber'].replace(' ', np.nan, inplace=True)
df_general.dropna(subset=['ProjectNumber'], inplace=True)
df_general.head()
# Out:
#                                                Agency  \
# 1   Andover, Town ofCentral Purchasing Department3...
# 4   Billerica, Town ofTown Manager's Office365 Bos...
# 6   Boston, City ofParks and Recreation Department...
# 7   Boston, City ofParks and Recreation Department...
# 13  Cambridge, City of Purchasing Department795 Ma...
#
#                 ContactEmail                          ContactName  \
# 1     twatkins@andoverma.gov  Thomas P. Watkins, Purchasing Agent
# 4   dmcsweeney@kvaboston.com                     Daniel McSweeney
# 6                                             Cathy Baker-Eclipse
# 7                                                 Allison Perlman
# 13    ehatch@cambridgema.gov                         Amy L. Witts
#
#     ContactPhone                  CustomId  \
# 1   978-623-8216  GC1/1/20161/10/201600001
# 4   857-300-6325  GC1/1/20161/10/201600004
# 6   617-961-3058  GC1/1/20161/10/201600006
# 7   617-635-4505  GC1/1/20161/10/201600007
# ...

# %%
df_award['ProjectNumber'].replace(' ', np.nan, inplace=True)
df_award.dropna(subset=['ProjectNumber'], inplace=True)
df_award.head()
# Out:
#                                               Agency  \
# 0  Bridgewater State UniversityProcurement Servic...
# 1  Gloucester, City of Purchasing Department9 Dal...
# 2  Lynn, City ofPurchasing Department3 City Hall ...
# 3  Mental Health, Department of (DMH)Office of En...
# 4  Newton, City of 1000 Commonwealth Ave.Newton, ...
#
#                                         ContactEmail      ContactName  \
# 0  Notify email address listed when final publish...    Diane Chagnon
# 1  Do not notify email address listed when final ...    Donna Compton
# 2  Notify email address listed when final publish...  Charles E White
# 3  Notify email address listed when final publish...     Sharon Moody
# 4  Do not notify email address listed when final ...        Nick Read
#
#    ContactPhone                   CustomId        ProjectNumber  \
# 0  508-531-2213  CAN1/1/20161/10/201600001  RFB No. 10 (FY16-2)
# 1  978-281-9710  CAN1/1/20161/10/201600002                16072
# ...

# %%
intersect = df_general[['Agency']].merge(df_award[['ProjectNumber', 'awarded_to']], on='ProjectNumber', how='left')
intersect
intersect.to_csv('output.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ProjectNumber'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-c6723446210a> in <module>()
# ...
